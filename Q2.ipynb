# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('best-fit.csv')
plt.scatter(df['X'],df['Y'])
plt.xlabel("X")
plt.ylabel("Y")
coefs = np.polyfit(df['X'],df['Y'],1)
m,c = coefs
y_fitted = m*df['X']+c
plt.plot(df['X'],y_fitted,1)
plt.show()
